# %% [markdown]
# <a href="https://colab.research.google.com/github/rajdeepd/tensorflow_2.0_book_code/blob/master/ch04/vgg19_all_images_25_epochs_colab_modelfit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
IN_COLAB = 'google.colab' in sys.modules
print('Google Colab? ' + str(IN_COLAB))

if not IN_COLAB:
#!python -m pip show tensorflow
  # !which python
  # !python -m pip show tensorflow
# Out:
# Google Colab? True

# %%
# !pwd
# Out:
# /content

# %%
from google.colab import drive
drive.mount("/content/gdrive")
# Out:
# Mounted at /content/gdrive

# %%
# !ls "/content/gdrive/My Drive/cancer_detection/metastatic_cancer"
# Out:
# model_summary		   training		validation
# plots_2.4.1_google_collab  training_logs_2.4.1

# %%
# %matplotlib inline

# %%
import sys
sys.executable
# Out:
# '/usr/bin/python3'

# %% [markdown]
# https://www.tensorflow.org/versions/r2.0/api_docs/python/tf/keras/applications/vgg19

# %%
# Imports
import numpy as np 
import pandas as pd 
from glob import glob 
from skimage.io import imread 
import os
import shutil
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.utils import plot_model
from tensorflow.keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D, Average, Input, Concatenate, GlobalMaxPooling2D
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import CSVLogger, ModelCheckpoint
from tensorflow.keras.optimizers import Adam

# %%
#!pip show tensorflow

# %%
if IN_COLAB:
  BASE = '/content/gdrive/My Drive/cancer_detection/metastatic_cancer'
else:
  BASE = '.'

# %%
# Output files
model_type='vgg16'
no_of_images = 'all'
EPOCHS = 25

if IN_COLAB:
  PLOTS = 'plots_2.4.1_google_collab'
  VERSION = '2.4.1'
else:
  PLOTS = 'plots_2.4.1'
  VERSION = '2.4.1' 
  
_APPEND = '_' + model_type + '_' + str(no_of_images) + '_' + str(EPOCHS)  
APPEND = _APPEND + ".png"


if IN_COLAB:
  if not os.path.exists(BASE + "/training_logs_" + VERSION):
    os.mkdir(BASE + "/training_logs_" + VERSION)

  if not os.path.exists(BASE + "/model_summary/"):
    os.mkdir(BASE + "/model_summary/")
  if not os.path.exists(BASE + "/model_summary/" + "model_summary_" + VERSION):
    os.mkdir(BASE + "/model_summary/" + "model_summary_" + VERSION)
  if not os.path.exists(BASE + '/' + PLOTS):
    os.mkdir(BASE + '/' + PLOTS)
if IN_COLAB:
  TRAINING_LOGS_FILE = BASE + "/training_logs_" + VERSION + '/training_logs' + _APPEND + '.csv'
  MODEL_SUMMARY_FILE = BASE + "/model_summary/" "model_summary_" + VERSION + "/model_summary" + _APPEND + ".txt"
  MODEL_PLOT_FILE = BASE + '/' + PLOTS + "/model_plot_" + APPEND
  MODEL_FILE = "model_" + VERSION + "/model_vgg16_all_collab.h5"
  TRAINING_PLOT_FILE = BASE + '/'+ PLOTS + "/training" +  APPEND
  VALIDATION_PLOT_FILE = BASE + '/'+  PLOTS + "/validation" + APPEND
  ROC_PLOT_FILE = BASE + '/'+  PLOTS + "/roc" + APPEND
else:
  TRAINING_LOGS_FILE = "training_logs_" + VERSION + '/training_logs' + _APPEND + '.csv'
  MODEL_SUMMARY_FILE = "model_summary_" + VERSION + "/model_summary" + _APPEND + ".txt"
  MODEL_PLOT_FILE = PLOTS + "/model_plot_" + APPEND
  MODEL_FILE = "model_" + VERSION + "/model_vgg16_all_collab.h5"
  TRAINING_PLOT_FILE = PLOTS + "/training" +  APPEND
  VALIDATION_PLOT_FILE = PLOTS + "/validation" + APPEND
  ROC_PLOT_FILE = PLOTS + "/roc" + APPEND

# %%
# Hyperparams
SAMPLE_COUNT = 85000
#TRAINING_RATIO = 0.9
IMAGE_SIZE = 96 
IMAGE_SIZE2 = 224

BATCH_SIZE = 192
VERBOSITY = 1
TESTING_BATCH_SIZE = 5000

# %%
import pathlib
data_dir = pathlib.Path(BASE)
data_dir
# Out:
# PosixPath('/content/gdrive/My Drive/cancer_detection/metastatic_cancer')

# %%
data_dir_training = pathlib.Path(BASE + '/training')

# %%
image_count = len(list(data_dir_training.glob('*/*.tif')))
print(image_count)
# Out:
# 360

# %%
import PIL
import PIL.Image
zeros = list(data_dir_training.glob('0/*'))
PIL.Image.open(str(zeros[0]))
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96 at 0x7F0F79224950>

# %%
import PIL
import PIL.Image
zeros = list(data_dir_training.glob('1/*'))
PIL.Image.open(str(zeros[0]))
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=RGB size=96x96 at 0x7F0F78B0AB10>

# %%
training_path=  BASE + '/training'
validation_path = BASE + '/validation'

# %%
#training, validation = train_test_split(data_frame, train_size=TRAINING_RATIO, stratify=data_frame['label'])

#data_frame.set_index('id', inplace=True)

# %%
# Data augmentation
training_data_generator = ImageDataGenerator(rescale=1./255,
                                             horizontal_flip=True,
                                             vertical_flip=True,
                                             rotation_range=180,
                                             zoom_range=0.4, 
                                             width_shift_range=0.3,
                                             height_shift_range=0.3,
                                             shear_range=0.3,
                                             channel_shift_range=0.3)

# %%
# Data generation
training_generator = training_data_generator.flow_from_directory(training_path,
                                                                 target_size=(IMAGE_SIZE2,IMAGE_SIZE2),
                                                                 batch_size=BATCH_SIZE,
                                                                 class_mode='binary')
validation_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(validation_path,
                                                                              target_size=(IMAGE_SIZE2,
                                                                                           IMAGE_SIZE2),
                                                                              batch_size=BATCH_SIZE,
                                                                              class_mode='binary')
testing_generator = ImageDataGenerator(rescale=1./255).flow_from_directory(validation_path,
                                                                           target_size=(IMAGE_SIZE2,IMAGE_SIZE2),
                                                                           batch_size=BATCH_SIZE,
                                                                           class_mode='binary',
                                                                           shuffle=False)
# Out:
# Found 360 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.
# Found 40 images belonging to 2 classes.

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.5.0

# %%
# Model
input_shape = (IMAGE_SIZE2, IMAGE_SIZE2, 3)
inputs = Input(input_shape)

vgg16 = VGG16(include_top=False, input_shape=(224, 224, 3))(inputs) 
outputs = GlobalAveragePooling2D()(vgg16)
outputs = Dropout(0.5)(outputs)
outputs = Dense(1, activation='sigmoid')(outputs)

model = Model(inputs, outputs)
model.compile(optimizer=Adam(lr=0.0001, decay=0.00001),
              loss='binary_crossentropy',
              metrics=['accuracy'])
model.summary()

plot_model(model,
           to_file=MODEL_PLOT_FILE,
           show_shapes=True,
           show_layer_names=True)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# vgg16 (Functional)           (None, 7, 7, 512)         14714688
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense (Dense)                (None, 1)                 513
# =================================================================
# Total params: 14,715,201
# Trainable params: 14,715,201
# Non-trainable params: 0
# _________________________________________________________________
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/optimizer_v2/optimizer_v2.py:375: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %%
import os
if not os.path.exists("training_logs_" + VERSION):
    os.makedirs("training_logs_" + VERSION)
file = open(TRAINING_LOGS_FILE, 'w+')

# %%
history = model.fit(training_generator,
                              steps_per_epoch=len(training_generator), 
                              validation_data=validation_generator,
                              validation_steps=len(validation_generator),
                              epochs=EPOCHS,
                              verbose=VERBOSITY,
                              callbacks=[#PlotLossesKeras(),
                                         ModelCheckpoint(MODEL_FILE,
                                                         monitor='val_accuracy',
                                                         verbose=VERBOSITY,
                                                         save_best_only=True,
                                                         mode='max'),
                                         CSVLogger(TRAINING_LOGS_FILE,
                                                   append=True,
                                                   separator=';')
                              ])
# Out:
# Epoch 1/25
# 2/2 [==============================] - 110s 31s/step - loss: 0.8263 - accuracy: 0.4861 - val_loss: 0.7119 - val_accuracy: 0.5000
#
# Epoch 00001: val_accuracy improved from -inf to 0.50000, saving model to model_2.4.1/model_vgg16_all_collab.h5
# Epoch 2/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.7644 - accuracy: 0.5000 - val_loss: 0.6951 - val_accuracy: 0.5000
#
# Epoch 00002: val_accuracy did not improve from 0.50000
# Epoch 3/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.7093 - accuracy: 0.5333 - val_loss: 0.6646 - val_accuracy: 0.6000
#
# Epoch 00003: val_accuracy improved from 0.50000 to 0.60000, saving model to model_2.4.1/model_vgg16_all_collab.h5
# Epoch 4/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.6864 - accuracy: 0.5222 - val_loss: 0.6448 - val_accuracy: 0.6000
#
# Epoch 00004: val_accuracy did not improve from 0.60000
# Epoch 5/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.6287 - accuracy: 0.6583 - val_loss: 0.6524 - val_accuracy: 0.6250
#
# Epoch 00005: val_accuracy improved from 0.60000 to 0.62500, saving model to model_2.4.1/model_vgg16_all_collab.h5
# Epoch 6/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.5201 - accuracy: 0.7556 - val_loss: 1.1535 - val_accuracy: 0.5750
#
# Epoch 00006: val_accuracy did not improve from 0.62500
# Epoch 7/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.6673 - accuracy: 0.6944 - val_loss: 0.7780 - val_accuracy: 0.6500
#
# Epoch 00007: val_accuracy improved from 0.62500 to 0.65000, saving model to model_2.4.1/model_vgg16_all_collab.h5
# Epoch 8/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.6099 - accuracy: 0.7583 - val_loss: 0.6543 - val_accuracy: 0.6000
#
# Epoch 00008: val_accuracy did not improve from 0.65000
# Epoch 9/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.6128 - accuracy: 0.6639 - val_loss: 0.6536 - val_accuracy: 0.5750
#
# Epoch 00009: val_accuracy did not improve from 0.65000
# Epoch 10/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.5440 - accuracy: 0.7167 - val_loss: 0.5805 - val_accuracy: 0.6500
#
# Epoch 00010: val_accuracy did not improve from 0.65000
# Epoch 11/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.5354 - accuracy: 0.7667 - val_loss: 0.5929 - val_accuracy: 0.8000
#
# Epoch 00011: val_accuracy improved from 0.65000 to 0.80000, saving model to model_2.4.1/model_vgg16_all_collab.h5
# Epoch 12/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.5339 - accuracy: 0.7583 - val_loss: 0.6653 - val_accuracy: 0.6250
#
# Epoch 00012: val_accuracy did not improve from 0.80000
# Epoch 13/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.4808 - accuracy: 0.7833 - val_loss: 0.7153 - val_accuracy: 0.6250
#
# Epoch 00013: val_accuracy did not improve from 0.80000
# Epoch 14/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4435 - accuracy: 0.8056 - val_loss: 0.6814 - val_accuracy: 0.7000
#
# Epoch 00014: val_accuracy did not improve from 0.80000
# Epoch 15/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.4623 - accuracy: 0.7833 - val_loss: 0.7124 - val_accuracy: 0.6250
#
# Epoch 00015: val_accuracy did not improve from 0.80000
# Epoch 16/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4438 - accuracy: 0.8167 - val_loss: 0.6721 - val_accuracy: 0.6750
#
# Epoch 00016: val_accuracy did not improve from 0.80000
# Epoch 17/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4716 - accuracy: 0.8083 - val_loss: 0.6621 - val_accuracy: 0.6750
#
# Epoch 00017: val_accuracy did not improve from 0.80000
# Epoch 18/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4710 - accuracy: 0.7972 - val_loss: 0.6395 - val_accuracy: 0.6250
#
# Epoch 00018: val_accuracy did not improve from 0.80000
# Epoch 19/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4753 - accuracy: 0.8028 - val_loss: 0.6426 - val_accuracy: 0.7000
#
# Epoch 00019: val_accuracy did not improve from 0.80000
# Epoch 20/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.4696 - accuracy: 0.8056 - val_loss: 0.6091 - val_accuracy: 0.7000
#
# Epoch 00020: val_accuracy did not improve from 0.80000
# Epoch 21/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4371 - accuracy: 0.8194 - val_loss: 0.6629 - val_accuracy: 0.6500
#
# Epoch 00021: val_accuracy did not improve from 0.80000
# Epoch 22/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4665 - accuracy: 0.8056 - val_loss: 0.6516 - val_accuracy: 0.7000
#
# Epoch 00022: val_accuracy did not improve from 0.80000
# Epoch 23/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.4554 - accuracy: 0.8139 - val_loss: 0.6151 - val_accuracy: 0.6500
#
# Epoch 00023: val_accuracy did not improve from 0.80000
# Epoch 24/25
# 2/2 [==============================] - 6s 2s/step - loss: 0.4261 - accuracy: 0.8139 - val_loss: 0.6730 - val_accuracy: 0.6750
#
# Epoch 00024: val_accuracy did not improve from 0.80000
# Epoch 25/25
# 2/2 [==============================] - 6s 3s/step - loss: 0.4446 - accuracy: 0.8167 - val_loss: 0.7101 - val_accuracy: 0.7000
#
# Epoch 00025: val_accuracy did not improve from 0.80000

# %%
history.history
# Out:
# {'accuracy': [0.4861111044883728,
#   0.5,
#   0.5333333611488342,
#   0.5222222208976746,
#   0.6583333611488342,
#   0.7555555701255798,
#   0.6944444179534912,
#   0.7583333253860474,
#   0.6638888716697693,
#   0.7166666388511658,
#   0.7666666507720947,
#   0.7583333253860474,
#   0.7833333611488342,
#   0.8055555820465088,
#   0.7833333611488342,
#   0.8166666626930237,
#   0.8083333373069763,
#   0.7972221970558167,
#   0.8027777671813965,
#   0.8055555820465088,
#   0.8194444179534912,
#   0.8055555820465088,
#   0.8138889074325562,
#   0.8138889074325562,
#   0.8166666626930237],
#  'loss': [0.826339066028595,
#   0.7643723487854004,
#   0.7092598676681519,
#   0.6864011287689209,
#   0.6287029385566711,
#   0.5201203227043152,
#   0.667327880859375,
#   0.6099150776863098,
#   0.6128482222557068,
#   0.5440062880516052,
#   0.5354341864585876,
#   0.5339164733886719,
#   0.48080191016197205,
#   0.44348305463790894,
#   0.4622569978237152,
#   0.4438185393810272,
#   0.47158482670783997,
#   0.4709835350513458,
#   0.4752872884273529,
#   0.46961891651153564,
#   0.4371195435523987,
#   0.4664793610572815,
#   0.45535627007484436,
#   0.4261067807674408,
#   0.44459402561187744],
#  'val_accuracy': [0.5,
#   0.5,
#   0.6000000238418579,
#   0.6000000238418579,
#   0.625,
#   0.574999988079071,
#   0.6499999761581421,
#   0.6000000238418579,
#   0.574999988079071,
#   0.6499999761581421,
#   0.800000011920929,
#   0.625,
#   0.625,
#   0.699999988079071,
#   0.625,
#   0.675000011920929,
#   0.675000011920929,
#   0.625,
#   0.699999988079071,
#   0.699999988079071,
#   0.6499999761581421,
#   0.699999988079071,
#   0.6499999761581421,
#   0.675000011920929,
#   0.699999988079071],
#  'val_loss': [0.7118932008743286,
#   0.6950874328613281,
#   0.6645548939704895,
#   0.644788384437561,
#   0.652367115020752,
#   1.1534879207611084,
#   0.7780383229255676,
#   0.6542626023292542,
#   0.6535521149635315,
#   0.5805383324623108,
#   0.5929009318351746,
#   0.6652947664260864,
#   0.7153214812278748,
#   0.6813524961471558,
#   0.7123845219612122,
#   0.6721435785293579,
#   0.6621374487876892,
#   0.6395457983016968,
#   0.6426199674606323,
#   0.6090682744979858,
#   0.6628705263137817,
#   0.6516176462173462,
#   0.6151061058044434,
#   0.6730300188064575,
#   0.7101345658302307]}

# %%
# Training plots
common_title = model_type + ' with ' + str(no_of_images) + ' samples'
epochs = [i for i in range(1, len(history.history['loss'])+1)]

plt.plot(epochs, history.history['loss'], color='blue', label="training_loss")
plt.plot(epochs, history.history['val_loss'], color='red', label="validation_loss")
plt.legend(loc='best')
#plt.title('training: ' + common_title)
plt.xlabel('epoch')
plt.savefig(TRAINING_PLOT_FILE, bbox_inches='tight')
plt.close()

plt.plot(epochs, history.history['accuracy'], color='blue', label="training_accuracy")
plt.plot(epochs, history.history['val_accuracy'], color='red',label="validation_accuracy")
plt.legend(loc='best')
plt.title('Validation (TF 2.5.0): ' + common_title )
plt.xlabel('epoch')
plt.savefig(VALIDATION_PLOT_FILE, bbox_inches='tight')
plt.show()
plt.close()

# %%
# ROC testing plot
#model.load_weights(MODEL_FILE)
predictions = model.predict_generator(testing_generator, steps=len(testing_generator), verbose=VERBOSITY)
false_positive_rate, true_positive_rate, threshold = roc_curve(testing_generator.classes, predictions)
area_under_curve = auc(false_positive_rate, true_positive_rate)

plt.plot([0, 1], [0, 1], 'k--')
plt.plot(false_positive_rate, true_positive_rate, label='AUC = {:.3f}'.format(area_under_curve))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve: ' + common_title + ' TF 2.4.1')
plt.legend(loc='best')
plt.savefig(ROC_PLOT_FILE, bbox_inches='tight')
plt.show()
plt.close()
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:2001: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   warnings.warn('`Model.predict_generator` is deprecated and '
# 1/1 [==============================] - 0s 280ms/step
